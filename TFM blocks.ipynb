# %% [markdown]
# # Diferentes tipos de recursos que se pueden incluir en un cuaderno Jupyter

# %% [markdown]
# ## Declaración de las librerias Python

# %%
from IPython.display import IFrame
from IPython.display import YouTubeVideo
import plotly.figure_factory as ff

# %% [markdown]
# ## Inclusión de recurso Youtube

# %%
YouTubeVideo('IGhjsc8lEKY', width=1000, height=500)

# %% [markdown]
# ## Inclusión de recurso para insertar contenido en PDF

# %%
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size

  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %%
PDF('piramide_matematica.pdf',size=(1000,750))
# Out:
# \includegraphics[width=1.0\textwidth]{piramide_matematica.pdf}

# %% [markdown]
# ## Inclusión de recurso para crear diagrama Gannt para ABP con Python

# %%
df = [dict(Task="Tarea-1", Start='2017-01-01', Finish='2017-02-02', Resource='Completado'),
      dict(Task="Tarea-1", Start='2017-02-15', Finish='2017-03-15', Resource='No completado'),
      dict(Task="Tarea-2", Start='2017-01-17', Finish='2017-02-17', Resource='No empezado'),
      dict(Task="Tarea-2", Start='2017-01-17', Finish='2017-02-17', Resource='Completado'),
      dict(Task="Tarea-3", Start='2017-03-10', Finish='2017-03-20', Resource='No empezado'),
      dict(Task="Tarea-3", Start='2017-04-01', Finish='2017-04-20', Resource='No empezado'),
      dict(Task="Tarea-3", Start='2017-05-18', Finish='2017-06-18', Resource='No empezado'),
      dict(Task="Tarea-4", Start='2017-01-14', Finish='2017-03-14', Resource='Completado')]

colors = {'No empezado': 'rgb(220, 0, 0)',
          'No completado': (1, 0.9, 0.16),
          'Completado': 'rgb(0, 255, 100)'}

fig = ff.create_gantt(df, colors=colors, index_col='Resource', show_colorbar=True,
                      group_tasks=True)
fig.show()
# Out:
# <div>                            <div id="1ed931b7-63f7-4f07-bee2-0856dbe8521d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ed931b7-63f7-4f07-bee2-0856dbe8521d")) {                    Plotly.newPlot(                        "1ed931b7-63f7-4f07-bee2-0856dbe8521d",                        [{"fill": "toself", "fillcolor": "rgb(0, 255, 100)", "hoverinfo": "name", "legendgroup": "rgb(0, 255, 100)", "mode": "none", "name": "Completado", "type": "scatter", "x": ["2017-01-01", "2017-02-02", "2017-02-02", "2017-01-01", "2017-01-01", "2017-01-17", "2017-02-17", "2017-02-17", "2017-01-17", "2017-01-17", "2017-01-14", "2017-03-14", "2017-03-14", "2017-01-14"], "y": [2.8, 2.8, 3.2, 3.2, null, 1.8, 1.8, 2.2, 2.2, null, -0.2, -0.2, 0.2, 0.2]}, {"fill": "toself"
# ...

# %% [markdown]
# ## Inclusión de recurso de creación de mapas mentales bubbl.us

# %%
IFrame(src='http://go.bubbl.us/b497ee/b15f?/UNIDAD-4', width='1000px', height='600px')
# Out:
#         <iframe
#             width="1000px"
#             height="600px"
#             src="http://go.bubbl.us/b497ee/b15f?/UNIDAD-4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso Geogebra

# %%
IFrame(src='https://www.geogebra.org/m/EeZMWrBu', width='1000px', height='600px')
# Out:
#         <iframe
#             width="1000px"
#             height="600px"
#             src="https://www.geogebra.org/m/EeZMWrBu"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso Ziteboard (para tomar apuntes o hacer cálculos)

# %%
IFrame("https://view.ziteboard.com/shared/89115773022618",width='1000px', height='600px')
# Out:
#         <iframe
#             width="1000px"
#             height="600px"
#             src="https://view.ziteboard.com/shared/89115773022618"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso de creación de rúbricas

# %%
IFrame("http://rubistar.4teachers.org/index.php?screen=ShowRubric&rubric_id=2866863&",width="1200px",height="800px")
# Out:
#         <iframe
#             width="1200px"
#             height="800px"
#             src="http://rubistar.4teachers.org/index.php?screen=ShowRubric&rubric_id=2866863&"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso DrawChat (para seguir una clase)

# %%
IFrame("https://draw.chat/C84811B5AEF38ABCC2A:rdmnidl3#p1,0,0,r0,s1",width="1000px",height="800px")
# Out:
#         <iframe
#             width="1000px"
#             height="800px"
#             src="https://draw.chat/C84811B5AEF38ABCC2A:rdmnidl3#p1,0,0,r0,s1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso Quizizz

# %%
IFrame("https://quizizz.com/admin/quiz/605a3c93e2b4eb001bd8cabb",width="1000px",height="500px")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="https://quizizz.com/admin/quiz/605a3c93e2b4eb001bd8cabb"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso GoConqr

# %%
IFrame("https://www.goconqr.com/es-ES/p/2074728-FACTORIZACION-DE-POLINOMIOS-mind_maps",width="1000px",height="500px")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="https://www.goconqr.com/es-ES/p/2074728-FACTORIZACION-DE-POLINOMIOS-mind_maps"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de recurso Kahoot (sólo para respuestas, la pregunta la enseña el profesor en la pantalla)

# %%
IFrame("https://kahoot.it",width="1000px",height="500px")
# Out:
#         <iframe
#             width="1000px"
#             height="500px"
#             src="https://kahoot.it"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de calculadora Descartes (proyectodescartes.org)

# %%
IFrame("https://proyectodescartes.org/calculadora/",width="1000px",height="550px")
# Out:
#         <iframe
#             width="1000px"
#             height="550px"
#             src="https://proyectodescartes.org/calculadora/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusion de unidad didáctica del proyecto Descartes

# %%
IFrame("https://proyectodescartes.org/miscelanea/materiales_didacticos/normal-JS/index.html",width="1000px",height="1000px")
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="https://proyectodescartes.org/miscelanea/materiales_didacticos/normal-JS/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Inclusión de código Python

# %%
def fact_recursividad(n):
    if n > 1:
        return n * fact_recursividad(n - 1)
    else:
        return 1
    
fact_recursividad(12)
# Out:
# 479001600

# %%
2+2
# Out:
# 4
